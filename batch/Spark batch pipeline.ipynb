# %%
#Apache Spark Libraries
import pyspark
from pyspark.sql import SparkSession
from pyspark import SparkConf
from pyspark.sql.functions import input_file_name, regexp_extract, regexp_replace, split, col




# Set configs
sparkConf = SparkConf()
sparkConf.setMaster("spark://spark-master:7077")
sparkConf.setAppName("batch_pipeline")
sparkConf.set("spark.driver.memory", "4g")
sparkConf.set("spark.executor.memory", "4g")
sparkConf.set("spark.executor.cores", "1")
sparkConf.set("spark.driver.cores", "1")

spark = SparkSession.builder.config(conf=sparkConf).getOrCreate()


# Setup hadoop fs configuration for schema gs://
conf = spark.sparkContext._jsc.hadoopConfiguration()
conf.set("fs.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem")
conf.set("fs.AbstractFileSystem.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS")

# Get bucket path
gcs_bucket_path = "bucket"

# Set file path
csv_files_path = gcs_bucket_path + "*.csv"

# Load Spark DF
df = spark.read.csv(csv_files_path, header=True, inferSchema=True)

print(f"Number of rows: {df.count()}")

# Extract the year from the filename (handles both YYYY and YYYY-MM-DD)
# Add a column with the file name
df = df.withColumn("filename", regexp_replace(input_file_name(), r"bucket", ""))

# Extract the year from the filename (handles both YYYY and YYYYMMDD patterns)
df = df.withColumn("year", regexp_extract("filename", r".*_(\d{2}\d{2})(\d{4})\.csv", 2).cast('int'))

# Extract net manager and type
df = df.withColumn('leverancier', split(col("filename"), '_').getItem(0))

# Check
df.printSchema()
df.show()
# Out:
# DataFrame 'coteq_electricity_2013' ingeladen, aantal rijen: 2503
# DataFrame 'coteq_electricity_2014' ingeladen, aantal rijen: 2503
# DataFrame 'coteq_electricity_2015' ingeladen, aantal rijen: 2503
# DataFrame 'coteq_electricity_2016' ingeladen, aantal rijen: 2503
# DataFrame 'coteq_electricity_2017' ingeladen, aantal rijen: 2503
# DataFrame 'coteq_electricity_2018' ingeladen, aantal rijen: 2503
# DataFrame 'coteq_electricity_2019' ingeladen, aantal rijen: 2563
# DataFrame 'coteq_electricity_2020' ingeladen, aantal rijen: 2575
# DataFrame 'endinet_electricity_01012011' ingeladen, aantal rijen: 5743
# DataFrame 'endinet_electricity_01012012' ingeladen, aantal rijen: 5795
# DataFrame 'endinet_electricity_01012013' ingeladen, aantal rijen: 5883
# DataFrame 'endinet_electricity_01012014' ingeladen, aantal rijen: 4546
# DataFrame 'endinet_electricity_01012015' ingeladen, aantal rijen: 4550
# DataFrame 'endinet_electricity_01012016' ingeladen, aantal rijen: 4565
# DataFrame 'enduriselectricity_01012013' ingeladen, aantal rijen: 9559
# DataFrame 'enduriselectricity_01012014' ingeladen, aantal rijen: 9572
# DataFrame 'enduriselectricity_01012015' ingeladen, aantal rijen: 9609
# DataFrame 'enduriselectricity_01012016' ingeladen, aantal rijen: 9646
# DataFrame 'enduriselectricity_01012017' ingeladen, aantal rijen: 9699
# DataFrame 'enduriselectricity_01012018' ingeladen, aantal rijen: 9751
# DataFrame 'enduriselectricity_01012019' ingeladen, aantal rijen: 9774
# DataFrame 'enexis_electricity_01012010' ingeladen, aantal rijen: 107512
# DataFrame 'enexis_electricity_01012011' ingeladen, aantal rijen: 108299
# DataFrame 'enexis_electricity_01012012' ingeladen, aantal rijen: 109808
# DataFrame 'enexis_electricity_01012013' ingeladen, aantal rijen: 113248
# DataFrame 'enexis_electricity_01012014' ingeladen, aantal rijen: 113644
# DataFrame 'enexis_electricity_01012015' ingeladen, aantal rijen: 113989
# DataFrame 'enexis_electricity_01012016' ingeladen, aantal rijen: 110577
# DataFrame 'enexis_electricity_01012017' ingeladen, aantal rijen: 115576
# DataFrame 'enexis_electricity_01012018' ingeladen, aantal rijen: 124163
# DataFrame 'enexis_electricity_01012019' ingeladen, aantal rijen: 124586
# DataFrame 'enexis_electricity_01012020' ingeladen, aantal rijen: 124877
# DataFrame 'liander_electricity_01012009' ingeladen, aantal rijen: 132655
# DataFrame 'liander_electricity_01012010' ingeladen, aantal rijen: 133554
# DataFrame 'liander_electricity_01012011' ingeladen, aantal rijen: 134371
# DataFrame 'liander_electricity_01012012' ingeladen, aantal rijen: 135181
# DataFrame 'liander_electricity_01012013' ingeladen, aantal rijen: 136040
# DataFrame 'liander_electricity_01012014' ingeladen, aantal rijen: 135737
# DataFrame 'liander_electricity_01012015' ingeladen, aantal rijen: 136238
# DataFrame 'liander_electricity_01012016' ingeladen, aantal rijen: 140639
# DataFrame 'liander_electricity_01012017' ingeladen, aantal rijen: 141484
# DataFrame 'liander_electricity_01012018' ingeladen, aantal rijen: 142265
# DataFrame 'liander_electricity_01012019' ingeladen, aantal rijen: 143131
# DataFrame 'liander_electricity_01012020' ingeladen, aantal rijen: 143886
# DataFrame 'rendo_electricity_2011' ingeladen, aantal rijen: 1473
# DataFrame 'rendo_electricity_2012' ingeladen, aantal rijen: 1476
# DataFrame 'rendo_electricity_2013' ingeladen, aantal rijen: 1470
# DataFrame 'rendo_electricity_2014' ingeladen, aantal rijen: 1467
# DataFrame 'rendo_electricity_2015' ingeladen, aantal rijen: 1470
# DataFrame 'rendo_electricity_2016' ingeladen, aantal rijen: 1466
# DataFrame 'rendo_electricity_2017' ingeladen, aantal rijen: 1473
# DataFrame 'rendo_electricity_2018' ingeladen, aantal rijen: 1486
# DataFrame 'rendo_electricity_2019' ingeladen, aantal rijen: 1487
# DataFrame 'stedin_electricity_2009' ingeladen, aantal rijen: 81514
# DataFrame 'stedin_electricity_2010' ingeladen, aantal rijen: 82074
# DataFrame 'stedin_electricity_2011' ingeladen, aantal rijen: 82549
# DataFrame 'stedin_electricity_2012' ingeladen, aantal rijen: 83000
# DataFrame 'stedin_electricity_2013' ingeladen, aantal rijen: 82687
# DataFrame 'stedin_electricity_2014' ingeladen, aantal rijen: 83004
# DataFrame 'stedin_electricity_2015' ingeladen, aantal rijen: 83388
# DataFrame 'stedin_electricity_2016' ingeladen, aantal rijen: 83791
# DataFrame 'stedin_electricity_2017' ingeladen, aantal rijen: 84190
# DataFrame 'stedin_electricity_2018' ingeladen, aantal rijen: 84695
# DataFrame 'stedin_electricity_2019' ingeladen, aantal rijen: 82204
# DataFrame 'stedin_electricity_2020' ingeladen, aantal rijen: 86338
# DataFrame 'westland-infra_electricity_2011' ingeladen, aantal rijen: 2358
# DataFrame 'westland-infra_electricity_2012' ingeladen, aantal rijen: 2369
# DataFrame 'westland-infra_electricity_2013' ingeladen, aantal rijen: 2397
# DataFrame 'westland-infra_electricity_2014' ingeladen, aantal rijen: 2422
# DataFrame 'westland-infra_electricity_2015' ingeladen, aantal rijen: 2440
# DataFrame 'westland-infra_electricity_2016' ingeladen, aantal rijen: 2464
# DataFrame 'westland-infra_electricity_2017' ingeladen, aantal rijen: 2493
# DataFrame 'westland-infra_electricity_2018' ingeladen, aantal rijen: 2518
# DataFrame 'westland-infra_electricity_2019' ingeladen, aantal rijen: 2324
# DataFrame 'westland-infra_electricity_2020' ingeladen, aantal rijen: 2557

# %%
from pyspark.sql.functions import sum as _sum, col

# Perform group by and aggregate
aggregated_df = df.groupBy("zipcode_from", "zipcode_to", "leverancier", "year").agg(
    _sum("annual_consume").alias("total_annual_consume"),
    _sum("num_connections").alias("total_num_connections")
)

# Calculate average consumption per connection
aggregated_df = aggregated_df.withColumn(
    "average_consumption",
    col("total_annual_consume") / col("total_num_connections")
)

# Show the result
aggregated_df.show()
print(f"Number of rows: {aggregated_df.count()}")
# Out:
# DataFrame 'coteq_electricity_2013' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'coteq_electricity_2014' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'coteq_electricity_2015' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'coteq_electricity_2016' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'coteq_electricity_2017' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'coteq_electricity_2018' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'coteq_electricity_2019' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'coteq_electricity_2020' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'endinet_electricity_01012011' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'endinet_electricity_01012012' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'endinet_electricity_01012013' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'endinet_electricity_01012014' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'endinet_electricity_01012015' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'endinet_electricity_01012016' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enduriselectricity_01012013' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enduriselectricity_01012014' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enduriselectricity_01012015' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enduriselectricity_01012016' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enduriselectricity_01012017' heeft de volgende kolommen:
# ['ï»¿NETBEHEERDER', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enduriselectricity_01012018' heeft de volgende kolommen:
# ['ï»¿NETBEHEERDER', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enduriselectricity_01012019' heeft de volgende kolommen:
# ['ï»¿NETBEHEERDER', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enexis_electricity_01012010' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'num_connections', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enexis_electricity_01012011' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'num_connections', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enexis_electricity_01012012' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'num_connections', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enexis_electricity_01012013' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'num_connections', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enexis_electricity_01012014' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'num_connections', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enexis_electricity_01012015' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'num_connections', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enexis_electricity_01012016' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'num_connections', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enexis_electricity_01012017' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'num_connections', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enexis_electricity_01012018' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enexis_electricity_01012019' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'enexis_electricity_01012020' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012009' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012010' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012011' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012012' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012013' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012014' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012015' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012016' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012017' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012018' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012019' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'liander_electricity_01012020' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'rendo_electricity_2011' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume']
# ----------------------------------------
# DataFrame 'rendo_electricity_2012' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume']
# ----------------------------------------
# DataFrame 'rendo_electricity_2013' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume']
# ----------------------------------------
# DataFrame 'rendo_electricity_2014' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume']
# ----------------------------------------
# DataFrame 'rendo_electricity_2015' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume']
# ----------------------------------------
# DataFrame 'rendo_electricity_2016' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume']
# ----------------------------------------
# DataFrame 'rendo_electricity_2017' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume']
# ----------------------------------------
# DataFrame 'rendo_electricity_2018' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume']
# ----------------------------------------
# DataFrame 'rendo_electricity_2019' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume']
# ----------------------------------------
# DataFrame 'stedin_electricity_2009' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'stedin_electricity_2010' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'stedin_electricity_2011' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'stedin_electricity_2012' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'stedin_electricity_2013' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'stedin_electricity_2014' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'stedin_electricity_2015' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'stedin_electricity_2016' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'stedin_electricity_2017' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'stedin_electricity_2018' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'stedin_electricity_2019' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'stedin_electricity_2020' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc', 'STANDAARDDEVIATIE']
# ----------------------------------------
# DataFrame 'westland-infra_electricity_2011' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', '%Defintieve aansl (NRM)', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'westland-infra_electricity_2012' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', '%Defintieve aansl (NRM)', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'westland-infra_electricity_2013' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', '%Defintieve aansl (NRM)', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'westland-infra_electricity_2014' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', '%Defintieve aansl (NRM)', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'westland-infra_electricity_2015' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'num_connections', 'delivery_perc', 'perc_of_active_connections', '%Defintieve aansl (NRM)', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc']
# ----------------------------------------
# DataFrame 'westland-infra_electricity_2016' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'perc_of_active_connections', '%Defintieve aansl (NRM)', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc', 'num_connections']
# ----------------------------------------
# DataFrame 'westland-infra_electricity_2017' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'perc_of_active_connections', '%Defintieve aansl (NRM)', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc', 'num_connections']
# ----------------------------------------
# DataFrame 'westland-infra_electricity_2018' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'perc_of_active_connections', '%Defintieve aansl (NRM)', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc', 'num_connections']
# ----------------------------------------
# DataFrame 'westland-infra_electricity_2019' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'perc_of_active_connections', '%Defintieve aansl (NRM)', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc', 'num_connections']
# ----------------------------------------
# DataFrame 'westland-infra_electricity_2020' heeft de volgende kolommen:
# ['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city', 'delivery_perc', 'perc_of_active_connections', '%Defintieve aansl (NRM)', 'type_conn_perc', 'type_of_connection', 'annual_consume', 'annual_consume_lowtarif_perc', 'smartmeter_perc', 'num_connections']
# ----------------------------------------

# %%
from pyspark.sql.functions import col, expr, lit, percentile_approx

# Step 1: Calculate Q1 and Q3
percentiles = aggregated_df.select(
    percentile_approx(col("average_consumption"), 0.25, lit(100)).alias("Q1"),
    percentile_approx(col("average_consumption"), 0.75, lit(100)).alias("Q3")
).collect()[0]

Q1, Q3 = percentiles.Q1, percentiles.Q3
IQR = Q3 - Q1

# Step 2: Calculate bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Step 3: Filter out outliers
filtered_df = aggregated_df.filter(
    (col("average_consumption") >= lower_bound) & (col("average_consumption") <= upper_bound)
)

# Show the result
print(f"Number of rows: {filtered_df.count()}")

# %%
# Load in geoJSON file and join it on the aggregate table
from pyspark.sql.functions import col, explode


geojson_df = spark.read.option("multiline", "true").json("file")

# Explode the "features" array to access individual features
geojson_df = geojson_df.select(explode(col("features")).alias("feature"))

# Extract geometry and properties, including 'pc4_code'
geojson_df = geojson_df.select(
    col("feature.geometry.type").alias("geometry_type"),
    col("feature.geometry.coordinates").alias("coordinates"),
    col("feature.properties.pc4_code").alias("pc4_code")
)

# Cast 'pc4_code' to Integer
geojson_df = geojson_df.withColumn("pc4_code", col("pc4_code").cast("int"))

# Show the DataFrame schema and a preview of the data
geojson_df.printSchema()
geojson_df.show(truncate=False)
# Out:
#           net_manager                          purchase_area         street  \
# 0  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.    Dorpsstraat
# 1  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.  De Stoevelaar
# 2  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.  De Stoevelaar
# 3  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.  De Stoevelaar
# 4  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.     Kerkstraat
#
#   zipcode_from zipcode_to   city  num_connections  delivery_perc  \
# 0       7468CP     7471AA  ENTER             19.0          89.47
# 1       7471AB     7471AB   GOOR             37.0         100.00
# 2       7471AC     7471AC   GOOR             16.0         100.00
# 3       7471AD     7471AE   GOOR             25.0          92.00
# 4       7471AG     7471AG   GOOR             14.0          85.71
#
#    perc_of_active_connections type_conn_perc type_of_connection  \
# 0                       94.74             89               1x35
# 1                      100.00             86               1x35
# 2                      100.00            100               1x35
# 3                       84.00             44               1x35
# 4                      100.00             36               1x35
#
#    annual_consume  annual_consume_lowtarif_perc  smartmeter_perc leverancier  \
# 0          4122.0                         89.47              0.0       coteq
# 1          1800.0                         94.59              0.0       coteq
# 2          1315.0                        100.00              0.0       coteq
# 3          6379.0                         92.00              0.0       coteq
# 4          4404.0                         92.86              0.0       coteq
#
#           type  jaar  ï»¿NETBEHEERDER STANDAARDDEVIATIE  \
# 0  electricity  2013              NaN               NaN
# 1  electricity  2013              NaN               NaN
# 2  electricity  2013              NaN               NaN
# 3  electricity  2013              NaN               NaN
# 4  electricity  2013              NaN               NaN
#
#    %Defintieve aansl (NRM)
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
